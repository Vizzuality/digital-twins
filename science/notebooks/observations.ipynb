# %%
import xarray as xr

# %%
ds = xr.load_dataset("../data/01_raw/obs/tasmax_201808.nc")["tasmax"]
ds
# Out:
# <xarray.DataArray 'tasmax' (time: 31, lat: 1801, lon: 3600)> Size: 804MB
# array([[[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         ...,
#         [224.2037 , 224.2037 , 224.20566, ..., 224.19785, 224.1998 ,
#          224.20175],
#         [224.20761, 224.20761, 224.20956, ..., 224.20175, 224.2037 ,
#          224.20566],
#         [222.33397, 222.33397, 222.33397, ..., 222.33397, 222.33397,
#          222.33397]],
#
#        [[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
# ...
# ...

# %%
r = ds.rio.write_crs(4326).rename(lon="x", lat="y").isel(time=1)

# %%
r.plot()

# %%
r.rio.clip_box(minx=-20, miny=35, maxx=20, maxy=55).plot(cmap="Spectral_r")

# %%
r.rio.coordinates
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 r.rio.coordinates
#
# AttributeError: 'RasterArray' object has no attribute 'coordinates'
